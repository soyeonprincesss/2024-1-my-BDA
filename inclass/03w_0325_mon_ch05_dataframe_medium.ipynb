# %% [markdown]
# <a href="https://colab.research.google.com/github/soyeonprincesss/2024-1-my-BDA/blob/main/inclass/03w_0325_mon_ch05_dataframe_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 빅데이터분석프로그래밍

# %% [markdown]
# ## A반 3주

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2
# 0.13.1

# %%
# 그림 선명하게
# %config lnlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10, 5, -3, 1])
plt.title('그래프 제목')
plt.xabel('직선')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-dd80bffbeffb> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import koreanize.matplotlib
#       3
#       4 plt.plot([-10, 5, -3, 1])
#       5 plt.title('그래프 제목')
#
# ModuleNotFoundError: No module named 'koreanize'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# | 함수 | 기능 |
# |------|------|
# |head()|앞부분 출력|

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 6.75 MiB/s, done.

# %%
import pandas as pd
exam = pd.read_csv("data/exam.csv")

# %% [markdown]
# ## mpg 데이터 파악하기

# %%
import pandas as pd
# mpg 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# %%
mpg.head(8)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
#
#   category
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact
# 6  compact
# 7  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.sample(10)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 189       toyota        camry solara    2.4  2008    4    auto(s5)   f   22
# 22     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 107        honda               civic    2.0  2008    4  manual(m6)   f   21
# 207   volkswagen                 gti    2.0  1999    4  manual(m5)   f   21
# 212   volkswagen               jetta    1.9  1999    4  manual(m5)   f   33
# 193       toyota             corolla    1.8  1999    4    auto(l3)   f   24
# 204       toyota   toyota tacoma 4wd    3.4  1999    6    auto(l4)   4   15
# 7           audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 115      hyundai             tiburon    2.0  1999    4    auto(l4)   f   19
# 110      hyundai              sonata    2.4  2008    4    auto(l4)   f   21
#
#      hwy fl    category
# 189   31  r     compact
# 22    17  r         suv
# 107   29  p  subcompact
# 207   29  r     compact
# 212   44  d     compact
# 193   30  r     compact
# 204   19  r      pickup
# 7     26  p     compact
# 115   26  r  subcompact
# 110   30  r     midsize

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include="all")
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# unique        10    3         NaN         NaN    5        7
# top     auto(l4)    f         NaN         NaN    r      suv
# freq          83  106         NaN         NaN  168       62
# mean         NaN  NaN   16.858974   23.440171  NaN      NaN
# std          NaN  NaN    4.255946    5.954643  NaN      NaN
# min          NaN  NaN    9.000000   12.000000  NaN      NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN      NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN      NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN      NaN
# max          NaN  NaN   35.000000   44.000000  NaN      NaN

# %%
mpg[["category"]]
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe()
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg[["manufacturer", "model", "trans", "drv", "fl", "category"]].describe()
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62

# %% [markdown]
# ## 범주형 데이터
#
# *   명목형
# *   순서형

# %%
mpg.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg[["fl", "category"]].value_counts()
# Out:
# fl  category
# r   suv           48
#     pickup        30
#     subcompact    29
#     midsize       26
#     compact       25
# p   compact       21
#     midsize       15
# r   minivan       10
# p   suv            8
#     2seater        5
# e   suv            4
# p   subcompact     3
# e   pickup         3
# d   suv            2
#     subcompact     2
#     compact        1
# e   minivan        1
# c   subcompact     1
# dtype: int64

# %%
mpg[["fl", "category"]].value_counts().to_frame()
# Out:
#                 0
# fl category
# r  suv         48
#    pickup      30
#    subcompact  29
#    midsize     26
#    compact     25
# p  compact     21
#    midsize     15
# r  minivan     10
# p  suv          8
#    2seater      5
# e  suv          4
# p  subcompact   3
# e  pickup       3
# d  suv          2
#    subcompact   2
#    compact      1
# e  minivan      1
# c  subcompact   1

# %% [markdown]
# ## 함수와 메서드 차이 알아보기
#
# *   함수(내장 함수)
# *   메소드
# *   패키지 함수

# %%
sum([4, 7, 8]) # 함수
# Out:
# 19

# %%
df = pd.DataFrame({'x' : [1, 2, 3]})
df.head()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ## 05-2 변수명 바꾸기(p113):시험예상

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'})
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(index = {0: "x", 1:"y", 2:"z"}, inplace=True)
df_new
# Out:
#    var1  var2  var3
# x     1     2    10
# y     2     3    20
# z     1     2    30

# %%
df = pd.DataFrame({"A": [1,2,3], "B":[4,5,6]})
df.rename(columns={"A":"a", "B":"c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ## 05-3파생변수 만들기:시험예상

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
#새로운 열 var_mean <- var1과 var2의 평균
df1["var_mean"] = (df1["var1"] + df1["var2"]) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      12
# 1     3     6      18
# 2     8     1      18

# %%
df2[["var1","var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df2["my_mean"] = df2[["var1", "var2"]].mean(axis=1) # 시험 예상
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2      12      3.0
# 1     3     6      18      4.5
# 2     8     1      18      4.5

# %% [markdown]
# ## mpg 통합 연비 변수 만들기

# %%
#mpg 데이터 불러오기
mpg=pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 127         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
# 126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 128         jeep  grand cherokee 4wd    5.7  2008    8    auto(l5)   4   13
# 230   volkswagen              passat    2.0  2008    4  manual(m6)   f   21
# 17          audi          a6 quattro    4.2  2008    8    auto(s6)   4   16
# 146       nissan              altima    3.5  2008    6    auto(av)   f   19
# 80          ford        explorer 4wd    4.0  2008    6    auto(l5)   4   13
# 173       toyota         4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#      hwy fl category
# 127   19  r      suv
# 126   12  e      suv
# 128   18  r      suv
# 230   29  p  midsize
# 17    23  p  midsize
# 146   26  p  midsize
# 80    19  r      suv
# 173   20  r      suv

# %%
# 통합 연비 변수(total) 만들기, total <= cty + hwy의 평균: 시험예상
mpg['total']=(mpg['cty'] + mpg['hwy']) / 2 #통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
# 통합 연비 변수(total) 만들기, total <= cty + hwy의 평균: 시험예상
mpg['mpg_mean']=mpg[['cty', 'hwy']].mean(axis='columns') #통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total'])/len(mpg) #total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg['total'].mean() # 통합 연비 변수 평균
# Out:
# 20.14957264957265

# %% [markdown]
# ## 조건문을 활용해 파생변수 만들기 (p118)

# %%
mpg['total'].describe() #기술(기초, 요약) 통계량 출력
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
#히스토그램, 도수분포표 만들기
mpg['total'].plot.hist();

# %%
mpg['total'].plot(kind="hist", title="히스토그램");
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
sns.histplot(mpg, x="total"); #x=mpg.total

# %% [markdown]
# ## 2.합결 판정 변수 만들기 p120

# %%
import numpy as np

# 20 이상이면 pass, 그렇지 않으면 fail 부여
mpg['test']=np.where(mpg['total']>=20, 'pass', 'fail')
mpg.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70         dodge  ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 194       toyota              corolla    1.8  1999    4    auto(l4)   f   24
# 184       toyota                camry    3.0  1999    6  manual(m5)   f   18
# 30     chevrolet      k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4   11
# 95          ford              mustang    4.6  1999    8  manual(m5)   r   15
# 97          ford              mustang    4.6  2008    8    auto(l5)   r   15
# 110      hyundai               sonata    2.4  2008    4    auto(l4)   f   21
# 118      hyundai              tiburon    2.0  2008    4    auto(l4)   f   20
# 62         dodge          durango 4wd    5.7  2008    8    auto(l5)   4   13
# 173       toyota          4runner 4wd    2.7  1999    4  manual(m5)   4   15
#
#      hwy fl    category  total  mpg_mean  test
# 70    15  r      pickup   13.0      13.0  fail
# 194   33  r     compact   28.5      28.5  pass
# 184   26  r     midsize   22.0      22.0  pass
# 30    15  r         suv   13.0      13.0  fail
# 95    22  r  subcompact   18.5      18.5  fail
# 97    22  r  subcompact   18.5      18.5  fail
# 110   30  r     midsize   25.5      25.5  pass
# 118   27  r  subcompact   23.5      23.5  pass
# 62    18  r         suv   15.5      15.5  fail
# 173   20  r         suv   17.5      17.5  fail

# %%
mpg['test'].value_counts() # 연비 합격 빈도표 만들기
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['total'].unique()
# Out:
# array([23.5, 25. , 25.5, 21. , 22. , 22.5, 20.5, 24. , 23. , 20. , 19.5,
#        17. , 13. , 15. , 14.5, 19. , 16.5, 12.5, 15.5, 26. , 21.5, 14. ,
#        18.5, 18. , 16. , 10.5, 13.5, 30.5, 28. , 28.5, 30. , 17.5, 27. ,
#        27.5, 26.5, 32.5, 38.5, 39.5, 35. , 24.5])

# %%
count_test = mpg['total'].value

# %%
count_test.plot.bar()

# %%
count_test.plot.bar(rot = 0) # 축 이름으로 수평 만들기

# %%
sns.countplot(mpg, x="test", hue=mpg.test);

# %%
sns.countplot(mpg, x="test", hue="test");

# %%
sns.countplot(data=mpg, x="test", hue="test", stat="percent"); # 시험 예상

# %%
sns.countplot(data=mpg, x="test", hue="cyl", stat="percent"); # 시험 예상

# %%
sns.countplot(data=mpg, x="test", hue="category", stat="percent"); # 시험 예상

# %% [markdown]
# ## 중첩 조건문 활용하기

# %%
# total 기준으로 A,B,C 등급 부여
mpg['grade'] = np.where(mpg['total']>=30, 'A',
               np.where(mpg['total']>=20, 'B', 'C'))

# 데이터 확인
mpg.sample(5)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 15          audi       a6 quattro    2.8  1999    6    auto(l5)   4   15   24
# 184       toyota            camry    3.0  1999    6  manual(m5)   f   18   26
# 98          ford          mustang    5.4  2008    8  manual(m6)   r   14   20
# 158      pontiac       grand prix    5.3  2008    8    auto(s4)   f   16   25
# 28     chevrolet  k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   14   19
#
#     fl    category  total  mpg_mean  test grade
# 15   p     midsize   19.5      19.5  fail     C
# 184  r     midsize   22.0      22.0  pass     B
# 98   p  subcompact   17.0      17.0  fail     C
# 158  p     midsize   20.5      20.5  pass     B
# 28   r         suv   16.5      16.5  fail     C

# %%
count_grade = mpg['grade'].value_counts()
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <Axes: >

# %%
count_grade = mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot = 0);

# %%
sns.countplot(mpg, x="grade", hue="grade");

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent');

# %%
mpg['grade'].value_counts().sort_index().index
Index(['A', 'B', 'C'], dtype='object')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-8bfb977726fc> in <cell line: 2>()
#       1 mpg['grade'].value_counts().sort_index().index
# ----> 2 Index(['A', 'B', 'C'], dtype='object')
#
# NameError: name 'Index' is not defined

# %%
mpg['grade'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg['grade'].unique()));
